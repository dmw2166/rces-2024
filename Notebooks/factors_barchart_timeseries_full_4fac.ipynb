# %%
import numpy as np
import seaborn as sns
import joblib
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib.dates as mdates
import matplotlib.ticker as mticker
from matplotlib.ticker import FuncFormatter

# %%
# force the math text to look normal
mpl.rcParams['mathtext.default'] = 'regular'

def major_ticks(x, pos=None):
    """Set the major ticks according 
    to this custom style
    """
    x = mdates.num2date(x)
    if pos == 0:
        fmt = "%-d\n%b %Y\n%I %p"
    else:
        fmt = "%-d"
    return x.strftime(fmt)

# set the default seaborn params
sns.set("paper", "ticks", color_codes=True, palette='colorblind')

# %%
#load in the comp data
comp = pd.read_csv('4_factor/res.csv')
comp.rename(columns={'Unnamed: 0':'species'},inplace=True)
comp
#comp.T.plot(kind='bar')
# Out:
#     species  Factor 1  Factor 2  Factor 3  Factor 4  Residual
# 0      bin0  0.000000  0.591610  0.017259  0.391704 -0.000572
# 1      bin1  0.198139  0.000000  0.000000  0.800360  0.001501
# 2      bin2  0.277755  0.000000  0.000000  0.798904 -0.076659
# 3      bin3  0.436055  0.000000  0.000000  0.657770 -0.093824
# 4      bin4  0.542970  0.000000  0.043076  0.455925 -0.041971
# 5      bin5  0.655051  0.000000  0.089361  0.265826 -0.010239
# 6   co_diff  0.802127  0.028422  0.042151  0.127308 -0.000009
# 7   no_diff  0.136463  0.000000  0.863331  0.000000  0.000206
# 8  no2_diff  0.853092  0.133808  0.000000  0.000000  0.013100
# 9   ox_diff  0.000000  0.955141  0.000000  0.000000  0.044859

# %%
comp2 = pd.melt(comp,id_vars='species', value_vars=['Factor 1','Factor 2','Factor 3','Factor 4','Residual'])
comp2
# Out:
#      species  variable     value
# 0       bin0  Factor 1  0.000000
# 1       bin1  Factor 1  0.198139
# 2       bin2  Factor 1  0.277755
# 3       bin3  Factor 1  0.436055
# 4       bin4  Factor 1  0.542970
# 5       bin5  Factor 1  0.655051
# 6    co_diff  Factor 1  0.802127
# 7    no_diff  Factor 1  0.136463
# 8   no2_diff  Factor 1  0.853092
# 9    ox_diff  Factor 1  0.000000
# 10      bin0  Factor 2  0.591610
# 11      bin1  Factor 2  0.000000
# 12      bin2  Factor 2  0.000000
# 13      bin3  Factor 2  0.000000
# 14      bin4  Factor 2  0.000000
# 15      bin5  Factor 2  0.000000
# 16   co_diff  Factor 2  0.028422
# 17   no_diff  Factor 2  0.000000
# 18  no2_diff  Factor 2  0.133808
# 19   ox_diff  Factor 2  0.955141
# 20      bin0  Factor 3  0.017259
# 21      bin1  Factor 3  0.000000
# 22      bin2  Factor 3  0.000000
# 23      bin3  Factor 3  0.000000
# 24      bin4  Factor 3  0.043076
# 25      bin5  Factor 3  0.089361
# 26   co_diff  Factor 3  0.042151
# 27   no_diff  Factor 3  0.863331
# 28  no2_diff  Factor 3  0.000000
# 29   ox_diff  Factor 3  0.000000
# 30      bin0  Factor 4  0.391704
# 31      bin1  Factor 4  0.800360
# 32      bin2  Factor 4  0.798904
# 33      bin3  Factor 4  0.657770
# 34      bin4  Factor 4  0.455925
# 35      bin5  Factor 4  0.265826
# 36   co_diff  Factor 4  0.127308
# 37   no_diff  Factor 4  0.000000
# 38  no2_diff  Factor 4  0.000000
# 39   ox_diff  Factor 4  0.000000
# 40      bin0  Residual -0.000572
# 41      bin1  Residual  0.001501
# 42      bin2  Residual -0.076659
# 43      bin3  Residual -0.093824
# 44      bin4  Residual -0.041971
# 45      bin5  Residual -0.010239
# 46   co_diff  Residual -0.000009
# 47   no_diff  Residual  0.000206
# 48  no2_diff  Residual  0.013100
# 49   ox_diff  Residual  0.044859

# %%
#load in timeseries data
ts = pd.read_csv('4_factor/timeseries.csv')
ts['localtime'] = pd.to_datetime(ts['localtime']) #convert timestamp column to pandas timestamp format
ts = ts.set_index('localtime',append=False) #setindex as local time
ts
#start = '2022-06-09 23:00'
#fin = '2022-06-12 00:00'
ts = ts.resample('D').mean()
ts
# Out:
#                Unnamed: 0       bin0       bin1      bin2      bin3      bin4  \
# localtime
# 2022-05-09    4248.347826  33.970732   3.958825  0.927110  0.178177  0.139509
# 2022-05-10    5260.019011  26.930940   3.559023  1.025867  0.232465  0.215039
# 2022-05-11    6322.487654  24.527172   3.519267  1.045256  0.263821  0.263804
# 2022-05-12    7273.383333  31.810357   3.854583  1.083390  0.255567  0.302507
# 2022-05-13    7655.114907  69.773974  11.649852  3.007800  0.667746  0.638377
# ...                   ...        ...        ...       ...       ...       ...
# 2022-11-09  162849.106157  14.130418   2.445980  0.618324  0.148975  0.230908
# 2022-11-10  163579.630901  10.951249   1.643178  0.360851  0.060274  0.064906
# 2022-11-11  164178.650165  13.183803   2.426721  0.699197  0.202506  0.348990
# 2022-11-12  165117.382353  10.938030   1.498432  0.369839  0.096067  0.154142
# 2022-11-13  165735.130435   7.596270   0.860024  0.259900  0.076143  0.119957
#
#                 bin5     co_diff    no_diff  no2_diff   ox_diff  Factor 1  \
# localtime
# 2022-05-09  0.080548  134.549379  11.423292  2.978571  4.344410  0.446194
# 2022-05-10  0.127619  245.407224  11.879848  4.145627  4.547529  0.930364
# 2022-05-11  0.148895  190.216667  17.765741  2.754630  3.762037  0.660204
# 2022-05-12  0.256130  257.295000  12.251667  3.410000  3.230000  0.970057
# 2022-05-13  0.372948  231.104037   8.866149  1.700000  2.904969  0.739763
# ...              ...         ...        ...       ...       ...       ...
# 2022-11-09  0.194418  180.642463   9.038004  3.899788  1.367304  0.684099
# 2022-11-10  0.035520  223.876395  20.300858  5.028755  2.300000  0.810994
# 2022-11-11  0.332863  253.612871  11.560396  4.939274  1.332673  0.980329
# 2022-11-12  0.133423  128.638235   6.278824  2.893235  1.413529  0.491264
# 2022-11-13  0.100130   56.200000   2.208696  1.156522  2.489130  0.214618
#
#             Factor 2  Factor 3  Factor 4
# localtime
# 2022-05-09  0.189883  0.345664  0.081694
# 2022-05-10  0.168826  0.339475  0.033358
# 2022-05-11  0.132975  0.539458  0.048295
# 2022-05-12  0.195177  0.351709  0.046168
# 2022-05-13  0.267233  0.255030  0.380697
# ...              ...       ...       ...
# 2022-11-09  0.074428  0.259587  0.033331
# 2022-11-10  0.056483  0.615008  0.003381
# 2022-11-11  0.072393  0.328034  0.021114
# 2022-11-12  0.067115  0.179503  0.012708
# 2022-11-13  0.050104  0.060299  0.009394
#
# [189 rows x 15 columns]

# %%
# set up the figure
fig = plt.figure(figsize=(9, 8))

    # build a gridspec-based layout
#gs = fig.add_gridspec(1, 5)

ax1 = fig.add_subplot(211)
ax2 = fig.add_subplot(212)

# %%
# Plot the timeseries

cols_to_plot = [col for col in ts.columns if "Factor" in col]

# %%
ax2.plot(ts[cols_to_plot[0]], lw=1, color=sns.xkcd_rgb['greyish'])
ax2.plot(ts[cols_to_plot[1]], lw=1, color=sns.xkcd_rgb['faded green'])
ax2.plot(ts[cols_to_plot[2]], lw=1, color=sns.xkcd_rgb['dusty purple'])
ax2.plot(ts[cols_to_plot[3]], lw=1, color=sns.xkcd_rgb['red'])

# %%
   # remove ticks on y axis
ax2.set_ylim(0, 2.5)
ax2.set_xlim(ts.index[0], ts.index[-1])
ax2.set_ylabel("Factor Intensity (a.u.)",fontsize=14)
ax2.legend([
        "Factor 1 ",
        "Factor 2 ",
        "Factor 3 ",
        "Factor 4"
    ], loc="upper right")

sns.despine()

# %%
cols = ['bin0', 'bin1', 'bin2','bin3','bin4','bin5','co_diff', 'ox_diff', 'no_diff', 'no2_diff']

pal = sns.color_palette()

colors = [pal[3], pal[2], pal[4], pal[5]]
colors += sns.color_palette("Blues", 6)
colors.reverse()
#colors

# %%
ax1 = sns.barplot(x='variable',y='value',
        data=comp2,
        ax=ax1, hue='species',hue_order=cols,
        palette=colors, saturation=1, edgecolor='black', linewidth=0.25,
        errwidth=.75)

# %%
ax1.set_ylim(0, 1)
ax1.set_xlabel("")
ax1.set_ylabel("Percent of Species Signal\nDescribed by Factor", fontsize=14)
ax1.set(yticks=np.linspace(0, 1, 11), yticklabels=["0","","","","","50","","","","","100"])
ax1.tick_params(axis='both', which='major', labelsize=14)

# %%
handles, _ = ax1.get_legend_handles_labels()
labels = ["Bin 0", "Bin 1", "Bin 2", "Bin 3","Bin 4","Bin 5","CO", "$O_3$", "$NO$", "$NO_2$",]
ax1.legend(handles, labels)

# %%
ax1.set_title('(a)',fontsize=14)
ax2.set_title('(b)',fontsize=14)

ax2.tick_params(axis='both', which='major', labelsize=14)

# %%
   # make the plots a bit shorter to make room for the figure sub-labels
#plt.subplots_adjust(top=.5)

    # add some figure text
plt.gcf().text(0.09, 0.9, "(a)", fontsize=12)
plt.gcf().text(0.5, 0.9, "(b)", fontsize=12)

plt.tight_layout()

fig.savefig('time_barchart_full_4fac.png', dpi=350)
